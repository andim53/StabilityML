# %% [markdown]
# # Analyze Models

# %%
def process(training_prop, model, experiment, path_to_ml_data):
    """
    Args:
        training_prop (str) - 'Ef' if models trained on formation energies; 'Ed' if decomposition energies
        model (str) - ML model
        experiment (str) - 'allMP', 'LiMnTMO', or 'smact'
        path_to_ml_data (os.PathLike) - path to ml_data directory in .../TestStabilityML/mlstabilitytest/ml_data
    
    Returns:
        Runs all relevant analyses
        Prints a summary
    """
    if (model == 'CGCNN') and (experiment == 'smact'):
        print('CGCNN cannot be applied directly to the SMACT problem because the structures are not known')
        return
    if ('random' in experiment) and (training_prop == 'Ed'):
        print('Random perturbations only apply to models trained on Ef as written')
        return
    if (experiment == 'classifier') and (training_prop == 'Ef'):
        print('Classifier experiment only applies to training on Ed')
        return
    if (model == 'CGCNN') and (training_prop == 'Ed'):
        print('CGCNN not trained on Ed')
        return
    data_dir = os.path.join(path_to_ml_data, training_prop, experiment, model)
    if not os.path.exists(data_dir):
        os.mkdir(data_dir)
        
    data_file = 'ml_input.json'
    finput = os.path.join(data_dir, data_file)
    if 'random' in experiment:
        src = finput.replace(experiment, 'allMP')
        copyfile(src, finput)
    if not os.path.exists(finput):
        print('missing data for %s-%s' % (model, experiment))
        return
    if training_prop == 'Ef':
        nprocs = 'all'
        obj = StabilityAnalysis(data_dir,
                                data_file,
                                experiment,
                                nprocs=nprocs)
    elif training_prop == 'Ed':
        obj = EdAnalysis(data_dir,
                         data_file,
                         experiment)
    else:
        raise NotImplementedError
    obj.results_summary
    print('got results')
    return

# %%
import os
from mlstabilitytest.stability.StabilityAnalysis import StabilityAnalysis, EdAnalysis
from shutil import copyfile

here = './mlstabilitytest/'

models = ['ElFrac', 'Meredig', 'Magpie', 'AutoMat', 'ElemNet', 'Roost', 
              'CGCNN']
experiments = ['LiMnTMO', 'allMP', 'smact',
               'random1', 'random2', 'random3',
               'classifier']
training_props = ['Ef', 'Ed']
path_to_ml_data = os.path.join(here, 'ml_data')

for training_prop in training_props:
    print('\n____ models trained on %s ____\n' % training_prop)
    for experiment in experiments:
        print('\n ~~~ %s ~~~\n' % experiment)
        experiment_dir = os.path.join(path_to_ml_data, training_prop, experiment)
        if (('random' not in experiment) and (training_prop == 'Ed')) or ((experiment != 'classifier') and (training_prop == 'Ef')):
            if not os.path.exists(experiment_dir):
                os.mkdir(experiment_dir)
        for model in models:
            print('\n %s ' % model)
            process(training_prop, model, experiment, path_to_ml_data)
# Out:
# ____ models trained on Ef ____
#
#
#  ~~~ LiMnTMO ~~~
#
#
#  ElFrac
#
# Checking input data...
# Data looks good.
# Time elapsed = 0 s.
#
# Reading existing results file: ./mlstabilitytest/ml_data/Ef/LiMnTMO/ElFrac/ml_results.json
#
# Summarizing performance...
#
# MAE on formation enthalpy = 0.099 eV/atom
# MAE on decomposition enthalpy = 0.064 eV/atom
#
# Classifying stable or unstable:
# Precision = 0.062
# Recall = 0.222
# Accuracy = 0.861
# F1 = 0.098
# FPR = 0.116
#
# Confusion matrix:
# TP | FP
# FN | TN =
# 2 | 30
# 7 | 228
#
# Time elapsed = 0 s
# got results
#
#  Meredig
#
# Checking input data...
# Data looks good.
# Time elapsed = 0 s.
#
# Reading existing results file: ./mlstabilitytest/ml_data/Ef/LiMnTMO/Meredig/ml_results.json
#
# Summarizing performance...
#
# MAE on formation enthalpy = 0.098 eV/atom
# MAE on decomposition enthalpy = 0.065 eV/atom
#
# Classifying stable or unstable:
# Precision = 0.062
# Recall = 0.222
# Accuracy = 0.861
# F1 = 0.098
# FPR = 0.116
#
# Confusion matrix:
# TP | FP
# FN | TN =
# 2 | 30
# 7 | 228
#
# Time elapsed = 0 s
# got results
#
#  Magpie
#
# Checking input data...
# Data looks good.
# Time elapsed = 0 s.
#
# Reading existing results file: ./mlstabilitytest/ml_data/Ef/LiMnTMO/Magpie/ml_results.json
#
# Summarizing performance...
#
# MAE on formation enthalpy = 0.060 eV/atom
# MAE on decomposition enthalpy = 0.052 eV/atom
#
# Classifying stable or unstable:
# Precision = 0.036
# Recall = 0.111
# Accuracy = 0.869
# F1 = 0.054
# FPR = 0.105
#
# Confusion matrix:
# TP | FP
# FN | TN =
# 1 | 27
# 8 | 231
#
# Time elapsed = 0 s
# got results
#
#  AutoMat
#
# Checking input data...
# Data looks good.
# Time elapsed = 0 s.
#
# Reading existing results file: ./mlstabilitytest/ml_data/Ef/LiMnTMO/AutoMat/ml_results.json
#
# Summarizing performance...
#
# MAE on formation enthalpy = 0.073 eV/atom
# MAE on decomposition enthalpy = 0.066 eV/atom
#
# Classifying stable or unstable:
# Precision = 0.111
# Recall = 0.333
# Accuracy = 0.888
# F1 = 0.167
# FPR = 0.093
#
# Confusion matrix:
# TP | FP
# FN | TN =
# 3 | 24
# 6 | 234
#
# Time elapsed = 0 s
# got results
#
#  ElemNet
#
# Checking input data...
# Data looks good.
# Time elapsed = 0 s.
#
# Reading existing results file: ./mlstabilitytest/ml_data/Ef/LiMnTMO/ElemNet/ml_results.json
#
# Summarizing performance...
#
# MAE on formation enthalpy = 0.045 eV/atom
# MAE on decomposition enthalpy = 0.043 eV/atom
#
# Classifying stable or unstable:
# Precision = 0.000
# Recall = 0.000
# Accuracy = 0.959
# F1 = 0.000
# FPR = 0.008
#
# Confusion matrix:
# TP | FP
# FN | TN =
# 0 | 2
# 9 | 256
#
# Time elapsed = 0 s
# got results
#
#  Roost
#
# Checking input data...
# Data looks good.
# Time elapsed = 0 s.
#
# Reading existing results file: ./mlstabilitytest/ml_data/Ef/LiMnTMO/Roost/ml_results.json
#
# Summarizing performance...
#
# MAE on formation enthalpy = 0.030 eV/atom
# MAE on decomposition enthalpy = 0.030 eV/atom
#
# Classifying stable or unstable:
# Precision = 0.000
# Recall = 0.000
# Accuracy = 0.929
# F1 = 0.000
# FPR = 0.039
#
# Confusion matrix:
# TP | FP
# FN | TN =
# 0 | 10
# 9 | 248
#
# Time elapsed = 0 s
# got results
#
#  CGCNN
#
# Checking input data...
# Data looks good.
# Time elapsed = 0 s.
#
# Reading existing results file: ./mlstabilitytest/ml_data/Ef/LiMnTMO/CGCNN/ml_results.json
#
# Summarizing performance...
#
# MAE on formation enthalpy = 0.014 eV/atom
# MAE on decomposition enthalpy = 0.014 eV/atom
#
# Classifying stable or unstable:
# Precision = 0.455
# Recall = 0.556
# Accuracy = 0.963
# F1 = 0.500
# FPR = 0.023
#
# Confusion matrix:
# TP | FP
# FN | TN =
# 5 | 6
# 4 | 252
#
# Time elapsed = 0 s
# got results
#
#  ~~~ allMP ~~~
#
#
#  ElFrac
#
# Checking input data...
# Data looks good.
# Time elapsed = 5 s.
#
# Reading existing results file: ./mlstabilitytest/ml_data/Ef/allMP/ElFrac/ml_results.json
#
# Summarizing performance...
#
# MAE on formation enthalpy = 0.231 eV/atom
# MAE on decomposition enthalpy = 0.143 eV/atom
#
# Classifying stable or unstable:
# Precision = 0.477
# Recall = 0.520
# Accuracy = 0.580
# F1 = 0.497
# FPR = 0.380
#
# Confusion matrix:
# TP | FP
# FN | TN =
# 17681 | 19411
# 16317 | 31605
#
# Time elapsed = 0 s
# got results
#
#  Meredig
#
# Checking input data...
# Data looks good.
# Time elapsed = 5 s.
#
# Reading existing results file: ./mlstabilitytest/ml_data/Ef/allMP/Meredig/ml_results.json
#
# Summarizing performance...
#
# MAE on formation enthalpy = 0.169 eV/atom
# MAE on decomposition enthalpy = 0.138 eV/atom
#
# Classifying stable or unstable:
# Precision = 0.510
# Recall = 0.598
# Accuracy = 0.609
# F1 = 0.550
# FPR = 0.384
#
# Confusion matrix:
# TP | FP
# FN | TN =
# 20347 | 19587
# 13651 | 31429
#
# Time elapsed = 0 s
# got results
#
#  Magpie
#
# Checking input data...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 25
#      23 for model in models:
#      24     print('\n %s ' % model)
# ---> 25     process(training_prop, model, experiment, path_to_ml_data)
#
# Cell In[1], line 39, in process(training_prop, model, experiment, path_to_ml_data)
#      37 if training_prop == 'Ef':
#      38     nprocs = 'all'
# ---> 39     obj = StabilityAnalysis(data_dir,
#      40                             data_file,
#      41                             experiment,
#      42                             nprocs=nprocs)
#      43 elif training_prop == 'Ed':
#      44     obj = EdAnalysis(data_dir,
#      45                      data_file,
#      46                      experiment)
#
# File ~/StabilityML/MyWorks/mlstabilitytest/stability/StabilityAnalysis.py:144, in StabilityAnalysis.__init__(self, data_dir, data_file, experiment, nprocs)
#     142 finput = os.path.join(data_dir, data_file)
#     143 input_data = read_json(finput)
# --> 144 input_data = {CompositionAnalysis(k).std_formula() : float(input_data[k])
#     145                 for k in input_data}
#     147 if experiment == 'allMP':
#     148     mp = Ef()
#
# File ~/StabilityML/MyWorks/mlstabilitytest/stability/StabilityAnalysis.py:144, in <dictcomp>(.0)
#     142 finput = os.path.join(data_dir, data_file)
#     143 input_data = read_json(finput)
# --> 144 input_data = {CompositionAnalysis(k).std_formula() : float(input_data[k])
#     145                 for k in input_data}
#     147 if experiment == 'allMP':
#     148     mp = Ef()
#
# File ~/StabilityML/MyWorks/mlstabilitytest/stability/CompositionAnalysis.py:127, in CompositionAnalysis.std_formula(self, reduce)
#     125 unreduced_formula = ''.join([''.join([el, str(el_to_amt[el])]) for el in sorted(list(el_to_amt.keys()))])
#     126 if reduce:
# --> 127     return self.reduce_formula(unreduced_formula)
#     128 else:
#     129     return unreduced_formula
#
# File ~/StabilityML/MyWorks/mlstabilitytest/stability/CompositionAnalysis.py:87, in CompositionAnalysis.reduce_formula(self, formula)
#      85 amt_combinations = list(combinations(amts, 2))
#      86 individual_gcds = [gcd(combination[0], combination[1]) for combination in amt_combinations]
# ---> 87 overall_gcd = np.min(individual_gcds)
#      88 new_amts = [int(amt/overall_gcd) for amt in amts]
#      89 return ''.join([els[i]+str(new_amts[i]) for i in range(len(els))])
#
# File ~/.conda/envs/StabilityML/lib/python3.11/site-packages/numpy/core/fromnumeric.py:2953, in min(a, axis, out, keepdims, initial, where)
#    2836 @array_function_dispatch(_min_dispatcher)
#    2837 def min(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2838         where=np._NoValue):
#    2839     """
#    2840     Return the minimum of an array or minimum along an axis.
#    2841
#    (...)
#    2951     6
#    2952     """
# -> 2953     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    2954                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/.conda/envs/StabilityML/lib/python3.11/site-packages/numpy/core/fromnumeric.py:88, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
#      86             return reduction(axis=axis, out=out, **passkwargs)
# ---> 88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# # Train a Models

# %%
from os.path import dirname, abspath, join
from sys import argv
import json
from mlstabilitytest.training.process import problem_dictionary, target_list, model_dictionary

base_path = './'
output_base_path = join(base_path, "mlstabilitytest", "ml_data")

"""
Train models on the MP data, and make predictions in a format suitable for hull analysis

"""
try:
    problem = argv[1]
    target = argv[2]
    model_name = argv[3]
except IndexError:
    print("Arguments should be Problem Target Model")
    exit(1)

try:
    train_func = problem_dictionary[problem]
except KeyError:
    print("Invalid problem selection {}. Valid choices are {}".format(problem,
                                                                      ", ".join(problem_dictionary.keys())))
    exit(1)
try:
    if not target in target_list:
        raise ValueError
except ValueError:
    print("Invalid target selection. Valid choices are {}".format(
        ", ".join(target_list)))
    exit(1)

try:
    model = model_dictionary[model_name](target)
except KeyError:
    print("Invalid model selection. Valid choices are {}".format(
        ", ".join(model_dictionary.keys())))
    exit(1)

output_file = join(output_base_path, target, problem,
                   model_name, 'ml_input.json')

print("Training {} to predict {} using the {} dataset".format(
    model_name, target, problem))

predictions = train_func(model, target)

print("Training complete, saving predictions to {}".format(output_file))
with open(output_file, 'w') as f:
    json.dump(predictions, f)
# Out:
# Arguments should be Problem Target Model
# Invalid problem selection -f. Valid choices are allMP, LiMnTMO, smact
# Invalid target selection. Valid choices are Ed, Ef
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 36
#      33     exit(1)
#      35 try:
# ---> 36     model = model_dictionary[model_name](target)
#      37 except KeyError:
#      38     print("Invalid model selection. Valid choices are {}".format(
#      39         ", ".join(model_dictionary.keys())))
#
# NameError: name 'model_name' is not defined

# %% [markdown]
# # Testing script for decomposition only

# %%
import os
from mlstabilitytest.stability.StabilityAnalysis import EdAnalysis
from shutil import copyfile

here = './mlstabilitytest/'

# models = ['ElFrac', 'Meredig', 'Magpie', 'AutoMat', 'ElemNet', 'Roost', 
#               'CGCNN']
model = 'Magpie'

experiment = 'LiMnTMO'
training_prop = 'Ed'
path_to_ml_data = os.path.join(here, 'ml_data')


data_dir = os.path.join(path_to_ml_data, training_prop, experiment, model)
data_file = 'ml_input.json'

obj = EdAnalysis(data_dir, data_file, experiment)

obj.results_summary
# Out:
# Checking input data...
# Data looks good.
# Time elapsed = 0 s.
#
# Reading existing results file: ./mlstabilitytest/ml_data/Ed/LiMnTMO/Magpie/ml_results.json
#
# Summarizing performance...
#
# MAE on decomposition enthalpy = 0.027 eV/atom
#
#
# Classifying stable or unstable:
# Precision = 0.000
# Recall = 0.000
# Accuracy = 0.966
# F1 = 0.000
# FPR = 0.000
#
# Confusion matrix:
# TP | FP
# FN | TN =
# 0 | 0
# 9 | 258
#
# Time elapsed = 0 s
